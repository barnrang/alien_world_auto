# %%
from PIL import Image
import io
import numpy as np

import selenium
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
selenium.__version__
# Out:
# '3.141.0'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mining_screen = plt.imread('alien_images/1.png')

# %%
loading_screen = plt.imread('alien_images/2.png')
finish_mining = plt.imread('alien_images/3.png')
finish_mining_2 = plt.imread('alien_images/4.png')

# %%
plt.imshow(mining_screen)

# %%
canvas = driver.find_element_by_id('unityContainer')


style_element = [x.strip() for x in canvas.get_attribute('style').split(';')]
width = int(style_element[0].split(' ')[-1][:-2])
height = int(style_element[1].split(' ')[-1][:-2])

# %%
canvas = driver.find_element_by_id('#canvas')
width = int(canvas.get_attribute('width'))
height = int(canvas.get_attribute('height'))

mining_height_ratio = 700 / height
mining_width_ratio = 1/2

# %%
width, height
# Out:
# (1036, 718)

# %%
webdriver.W

# %%
def press_mining(posx=0, posy=0):
    print(int(mining_height_ratio * height), int(mining_width_ratio * width))
    action = webdriver.common.action_chains.ActionChains(driver)
    action.move_to_element_with_offset(canvas, int(mining_height_ratio * height), int(mining_width_ratio * width))
#     action.move_to_element(canvas)
#     action.move_to_element

#     action.move_by_offset(posx, posy)
#     action.move_by_offset(- width//2 + 10, height //2 - 10)
    action.move_to_element_with_offset(canvas, posx, posy)
    action.click()
    action.perform()

def press_collect_token():
    pass

# %%
mining_pos = (510, 600)
claim_pos = (510, 400)
return_to_mining_pos = (200, 560)

# %%
while True:
    print('Prepare to mine')
    while not check_if_can_mine():
        time.sleep(20)
    press_mining(*mining_pos)
    
    print('Prepare to claim')
    while not check_if_can_claim():
        time.sleep(20)
    press_mining(*claim_pos)
    
    print('Prepare to return')
    while not check_if_can_return():
        time.sleep(20)
    press_mining(*return_to_mining)
# Out:
# Prepare to mine
# 559 518
# Prepare to mine
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-313-9da2ea9c64c5> in <module>
#       2     print('Prepare to mine')
#       3     while not check_if_can_mine():
# ----> 4         time.sleep(30)
#       5     press_mining(*mining_pos)
#       6
#
# KeyboardInterrupt:

# %%
data = driver.get_screenshot_as_png()

img = Image.open(io.BytesIO(data))

claim_button = np.asarray(img)

plt.imshow(claim_button[350:400, 350:400])

# %%
data = driver.get_screenshot_as_png()

img = Image.open(io.BytesIO(data))

return_to_mine = np.asarray(img)

plt.imshow(return_to_mine[680:700, 250:300])

# %%
plt.imsave('alien_images/return_to_mine', return_to_mine[680:700, 250:300])

# %%
plt.imsave('alien_images/claim_button', claim_button[400:450, 400:450])

# %%
claim_button[400:450, 400:450]
# Out:
# array([[[  0,  24,  41, 255],
#         [  0,  24,  41, 255],
#         [  0,  24,  41, 255],
#         ...,
#         [  0,  24,  41, 255],
#         [  0,  24,  41, 255],
#         [  0,  24,  41, 255]],
#
#        [[  0,  23,  42, 255],
#         [  0,  23,  42, 255],
#         [  0,  23,  42, 255],
#         ...,
#         [  0,  23,  42, 255],
#         [  0,  23,  42, 255],
#         [  0,  23,  42, 255]],
#
#        [[  0,  23,  43, 255],
#         [  0,  23,  43, 255],
#         [  0,  23,  43, 255],
#         ...,
#         [  0,  23,  43, 255],
#         [  0,  23,  43, 255],
#         [  0,  23,  43, 255]],
#
#        ...,
#
#        [[  0,  17,  32, 255],
#         [  0,  17,  32, 255],
#         [  0,  17,  32, 255],
#         ...,
#         [  0,  17,  32, 255],
#         [  0,  17,  32, 255],
#         [  0,  17,  32, 255]],
#
#        [[  0,  17,  32, 255],
#         [  0,  17,  32, 255],
#         [  0,  17,  32, 255],
#         ...,
#         [  0,  17,  32, 255],
#         [  0,  17,  32, 255],
#         [  0,  17,  32, 255]],
#
#        [[  0,  17,  32, 255],
#         [  0,  17,  32, 255],
#         [  0,  17,  32, 255],
#         ...,
#         [  0,  17,  32, 255],
#         [  0,  17,  32, 255],
#         [  0,  17,  32, 255]]], dtype=uint8)

# %%
mining_button_ref = plt.imread('alien_images/mining_button.png')
claim_button_ref = plt.imread('alien_images/claim_button.png')
return_to_mine_ref = plt.imread('alien_images/return_to_mine.png')

def check_if_can_mine():
    data = driver.get_screenshot_as_png()
    img = Image.open(io.BytesIO(data))
    mining_button = np.asarray(img)[740:760, 600:650].astype(np.float32) / 255.
    return (np.mean(np.abs(mining_button_ref - mining_button)) < 0.01)

def check_if_can_claim():
    data = driver.get_screenshot_as_png()
    img = Image.open(io.BytesIO(data))
    mining_button = np.asarray(img)[400:450, 400:450].astype(np.float32) / 255.
    return (np.mean(np.abs(claim_button_ref - mining_button)) < 0.01)

def check_if_can_return():
    data = driver.get_screenshot_as_png()
    img = Image.open(io.BytesIO(data))
    mining_button = np.asarray(img)[680:700, 250:300].astype(np.float32) / 255.
    return (np.mean(np.abs(return_to_mine_ref - mining_button)) < 0.01)

# %%
press_mining(*return_to_mining_pos)
# Out:
# 559 518

# %%
check_if_can_return()
# Out:
# True

# %%
data = driver.get_screenshot_as_png()
img = Image.open(io.BytesIO(data))
tmp = np.asarray(img)[740:760, 600:650].astype(np.float32) / 255.

# %%
mining_button_ref - tmp
# Out:
# array([[[-0.23529412, -0.3411765 , -0.32156864,  0.        ],
#         [-0.23921569, -0.3411765 , -0.32156864,  0.        ],
#         [-0.24705882, -0.33725494, -0.3137255 ,  0.        ],
#         ...,
#         [-0.2784314 , -0.32549024, -0.2784314 ,  0.        ],
#         [-0.2784314 , -0.30980396, -0.24313727,  0.        ],
#         [-0.09803922, -0.16862747, -0.12156862,  0.        ]],
#
#        [[-0.22352941, -0.3176471 , -0.2784314 ,  0.        ],
#         [-0.21960784, -0.30196083, -0.26666668,  0.        ],
#         [-0.22745098, -0.29803926, -0.2627451 ,  0.        ],
#         ...,
#         [-0.2627451 , -0.30196083, -0.25882354,  0.        ],
#         [-0.2627451 , -0.29803926, -0.227451  ,  0.        ],
#         [-0.05882354, -0.13725492, -0.10588235,  0.        ]],
#
#        [[-0.19607843, -0.28627455, -0.24313727,  0.        ],
#         [-0.18431373, -0.27058828, -0.23137257,  0.        ],
#         [-0.19607843, -0.27058828, -0.23137257,  0.        ],
#         ...,
#         [-0.2627451 , -0.3058824 , -0.2627451 ,  0.        ],
#         [-0.2627451 , -0.29803926, -0.227451  ,  0.        ],
#         [-0.04705884, -0.13333336, -0.09803921,  0.        ]],
#
#        ...,
#
#        [[-0.10196079, -0.12941177, -0.0901961 ,  0.        ],
#         [-0.10588235, -0.13333334, -0.0901961 ,  0.        ],
#         [-0.11372549, -0.14117648, -0.09803924,  0.        ],
#         ...,
#         [-0.16470589, -0.18431373, -0.12156865,  0.        ],
#         [-0.15686275, -0.17254902, -0.10588238,  0.        ],
#         [-0.16862746, -0.18431373, -0.11764708,  0.        ]],
#
#        [[-0.11372549, -0.14509805, -0.09411767,  0.        ],
#         [-0.11372549, -0.14509805, -0.09411767,  0.        ],
#         [-0.11764706, -0.14901961, -0.09803924,  0.        ],
#         ...,
#         [-0.16862746, -0.1882353 , -0.12549022,  0.        ],
#         [-0.16862746, -0.18431373, -0.12156865,  0.        ],
#         [-0.1764706 , -0.19215687, -0.12549022,  0.        ]],
#
#        [[-0.09803922, -0.13725491, -0.10196081,  0.        ],
#         [-0.10196079, -0.13725491, -0.10196081,  0.        ],
#         [-0.09019608, -0.12156864, -0.08235297,  0.        ],
#         ...,
#         [-0.15686275, -0.1764706 , -0.12941179,  0.        ],
#         [-0.14509805, -0.16470589, -0.11764708,  0.        ],
#         [-0.13725491, -0.15294118, -0.10588238,  0.        ]]],
#       dtype=float32)

# %%
np.mean(mining_button_ref - tmp) < 1e-8
# Out:
# True

# %%
plt.imshow(mining_button_ref)

# %%
plt.imshow(tmp)

# %%
tmp
# Out:
# array([[[  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         ...,
#         [  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         [ 42,  91, 135, 255]],
#
#        [[  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         ...,
#         [  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         [ 56, 102, 143, 255]],
#
#        [[  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         ...,
#         [  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         [ 58, 103, 144, 255]],
#
#        ...,
#
#        [[  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         ...,
#         [  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         [  0,  59, 112, 255]],
#
#        [[  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         ...,
#         [  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         [  0,  59, 112, 255]],
#
#        [[  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         ...,
#         [  0,  59, 112, 255],
#         [  0,  59, 112, 255],
#         [  0,  59, 112, 255]]], dtype=uint8)

# %%
mining_button_ref
# Out:
# array([[[0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         ...,
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.16470589, 0.35686275, 0.5294118 , 1.        ]],
#
#        [[0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         ...,
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.21960784, 0.4       , 0.56078434, 1.        ]],
#
#        [[0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         ...,
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.22745098, 0.40392157, 0.5647059 , 1.        ]],
#
#        ...,
#
#        [[0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         ...,
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ]],
#
#        [[0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         ...,
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ]],
#
#        [[0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         ...,
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ],
#         [0.        , 0.23137255, 0.4392157 , 1.        ]]], dtype=float32)

# %%
np.abs(mining_button_ref - tmp).astype(np.uint8)
# Out:
# array([[[  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         ...,
#         [  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         [ 41,  90, 134, 254]],
#
#        [[  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         ...,
#         [  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         [ 55, 101, 142, 254]],
#
#        [[  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         ...,
#         [  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         [ 57, 102, 143, 254]],
#
#        ...,
#
#        [[  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         ...,
#         [  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         [  0,  58, 111, 254]],
#
#        [[  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         ...,
#         [  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         [  0,  58, 111, 254]],
#
#        [[  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         ...,
#         [  0,  58, 111, 254],
#         [  0,  58, 111, 254],
#         [  0,  58, 111, 254]]], dtype=uint8)

# %%
plt.imshow(np.abs(mining_button_ref - tmp).astype(np.uint8))

# %%
check_if_can_mine()
# Out:
# False

# %%
new_img = mining_button[740:760, 600:650]

# %%
plt.imsave('alien_images/mining_button', new_img)

# %%
plt.imshow(new_img)

# %%
data = driver.get_screenshot_as_png()

img = Image.open(io.BytesIO(data))

no_mining_button = np.asarray(img)

plt.imshow(no_mining_button)

# %%
i,j
# Out:
# (100, 400)

# %%
for i in range(0, width, 50):
    for j in range(0, height, 50):
        press_mining(posx=i, posy=j)
# Out:
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# 559 518
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Miniconda3\envs\deeplr\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-207-b8033b51acf9> in <module>
#       1 for i in range(0, width, 50):
#       2     for j in range(0, height, 50):
# ----> 3         press_mining(posx=i, posy=j)
#
# <ipython-input-200-64e27ff6f851> in press_mining(posx, posy)
#      10     action.move_to_element_with_offset(canvas, posx, posy)
#      11     action.click()
# ---> 12     action.perform()
#      13
#      14 def press_collect_token():
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\selenium\webdriver\common\action_chains.py in perform(self)
#      78         """
#      79         if self._driver.w3c:
# ---> 80             self.w3c_actions.perform()
#      81         else:
#      82             for action in self._actions:
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\selenium\webdriver\common\actions\action_builder.py in perform(self)
#      74             if encoded['actions']:
#      75                 enc["actions"].append(encoded)
# ---> 76         self.driver.execute(Command.W3C_ACTIONS, enc)
#      77
#      78     def clear_actions(self):
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     321             response = conn.urlopen(method, url, **kw)
#     322         else:
# --> 323             response = conn.urlopen(method, u.request_uri, **kw)
#     324
#     325         redirect_location = redirect and response.get_redirect_location()
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Miniconda3\envs\deeplr\lib\http\client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~\Miniconda3\envs\deeplr\lib\http\client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~\Miniconda3\envs\deeplr\lib\http\client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~\Miniconda3\envs\deeplr\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
int(mining_height_ratio * height), int(mining_width_ratio * width)
# Out:
# (746, 647)

# %%
mining_height_ratio * height
# Out:
# 421.5

# %%
from selenium import webdriver
import chromedriver_binary
import time

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://play.alienworlds.io/')

# %%
width = canvas.get_attribute('width')
height = canvas.get_attribute('height')

# %%
canvas
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="58ca07ddf735d7a4da229b1335f50498", element="2c1ee0e4-edfb-4a35-b53c-d46477e07d6e")>

# %%
from selenium.webdriver.support import expected_conditions as EC

# %%
canvas

# %%
data = driver.get_screenshot_as_png()

# %%
img = Image.open(io.BytesIO(data))

numpy_array = np.asarray(img)

plt.imshow(numpy_array)

# %%
numpy_array.shape[0]
# Out:
# 843

# %%
diff_h = -numpy_array.shape[0] + height
# diff_w = -numpy_array.shape[1] + width
test = numpy_array[diff_h//2:-diff_h//2]

# %%
numpy_array.shape
# Out:
# (843, 1295, 4)

# %%
height, width
# Out:
# (843, 1295)

# %%
plt.imshow(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-aa092d62cf54> in <module>
# ----> 1 plt.imshow(test)
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2697         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2698         resample=resample, url=url, **({"data": data} if data is not
# -> 2699         None else {}), **kwargs)
#    2700     sci(__ret)
#    2701     return __ret
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5492                               resample=resample, **kwargs)
#    5493
# -> 5494         im.set_data(X)
#    5495         im.set_alpha(alpha)
#    5496         if im.get_clip_path() is None:
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     644             # making reliable interpretation impossible.
#     645             high = 255 if np.issubdtype(self._A.dtype, np.integer) else 1
# --> 646             if self._A.min() < 0 or high < self._A.max():
#     647                 _log.warning(
#     648                     'Clipping input data to the valid range for imshow with '
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\numpy\ma\core.py in min(self, axis, out, fill_value, keepdims)
#    5671         if out is None:
#    5672             result = self.filled(fill_value).min(
# -> 5673                 axis=axis, out=out, **kwargs).view(type(self))
#    5674             if result.ndim:
#    5675                 # Set the mask
#
# ~\Miniconda3\envs\deeplr\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      32 def _amin(a, axis=None, out=None, keepdims=False,
#      33           initial=_NoValue, where=True):
# ---> 34     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      35
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
test.shape
# Out:
# (0, 1295, 4)

# %%
diff_h, diff_w
# Out:
# (193, -621)

# %%
numpy_array.shape[1]
# Out:
# 1295
